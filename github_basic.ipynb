# %% [markdown]
# ## Git Basic commands
# - First create a new repository in Github
#     - Go to github
#     - Create New
#     - For the time being leave all options as default and make it public.
#     - `Click Create`
#     - `Clicking Create` will take you to a page with basic git commands to help comit the file.
# - Create a directory using the terminal
#     - use `ls` command to display all the folders in the current directory.
#     - use `cd <directory name >to enter into any dircetory.
#         - use the entire path insted of single directory name if you know it.
#         - **note**
#             - if the directory names contains spaces, terminal commands may not recognise it.
#             - use`my_directory' instead of `my directory'
#     - create new dir using command `mkdir <dir name>
#     - Enter the new dir created using `cd <dir name>'
#     - **Follow the instructions in the github page**
#         - first comd is `echo`
#             - syntax is echo "# Github_Basics" >> README.md
#                 - What ever is in the "" will get written to a file named README.md
#             - here we are creating a simple Readme file with a single line in it.
#             - use `ls` and see that README.md is displayed
#             - `cat <filename>` in this case `cat <README.md>`
#                 - cat command wwill display what is in the file
#          - Initilising a Git repository for the forlder which is created
#             - use command `git init`
#             - this will initiate an empty repository for the folder and will track all the changes and files in it.
#          - Configuring git
#             - This is a one time measure and need not be repeated here after.
#             - This is done to connect the local machine with github.
#             - Configuration is done based on email and username. For this we use the following commands
#                 - `git config user.name <your github username>`
#                 -  `git config user.email <your username liked to github profile>`
#                 - It will ask for password then use the token as passwords are now obselete in git.
#
#             - Check if the config is working use
#                 - `git config user.name` & `git config user.email` and it will show you the user name and email
#         - Adding new file
#             - before adding check the status using `git status`
#             - At this stage this command will show the README.md file in read as it is untracked.
#             - it will also display 'No commits yet' , 'Nothing added to commit but untracked files present'
#             - `git add <file name>` to add the file to staging and then check status again.
#                 - Adding file will take it to tracking mode from untrack mode.
#                 - Status will show the file in green, bust will still show no commits yet
#         - Commiting the added file
#             - use `git comit -m "<message>"
#             - -m stands for message and whatever is written in " " followed by -m will be displayed along with the commited file.
#             - messages are useful while colaborating or looking at the files later to see what was it about.
#             - Press enter and the message will be shown along with 1 file change/// 1 insertion. This means we have added one new file
#             - use `git status' and we see the display saying nothing to commit.
#
#         - Renaming the branch
#             - use `git branch -M <new name>`
#             - This will change the name of the branch to  'new name' you wish to give.
#             - for eg you cna change default 'master' to 'main'
#             - `git branch` will display the current branch you are working on.
#         - Linking repository and local machine folder.
#             - Before we can push the files to git repository we need to link th efolder in th elocal machine and the repository
#             - Please note that we did the config and that was a one time thing.
#             - But for every repository we need to link the repository url to the folder in the local machine.
#             - For this go to the github and copy the url, then use following command
#             - `git remote add origin <url>`
#
#         - Pushing the file to the repository
#             - use `git -u push origin <branch name>'
#             - At this stage the system will ask for user name and password
#             - type in the username and passowrd prompt will be shown
#             - Getting token.
#                 - PAsswords ar eno more permitted in git, so we need access token.
#                 - Go to github page and click on the photo in the upper right hand corner.
#                 - go to <settings>
#                 - scroll down to <developer settings>
#                 - go to <personal access token>
#                 - Write a note to enable further refrence or use of token
#                 - click on <generate new token>
#                 - This will show lot of options which you may select as per requirement.
#                 - scroll down to the end and click <generate>
#                 - A new token is genrated
#                 - copy the token
#              - paste the token in the password prompt at terminal
#                 - note that the password is not displayed and hence repasting it will be treated as a wrong token.
#             - it will show master -> master which means its writng from amster in local machine to master in repository.
#         - Go to github page and click on the repository
#             - you can see the new README.md file created

# %% [markdown]
# ### Adding More Code
# - Use of VS Code
# - oen the current folder from th open menu in the top ribbon.
# - click on the README file and we can see the entire file
# - For eg of adding new file:
#     - go to new file and create a new file called `data_processing`
#     - enter your desired code and save the file
# - Next we have to push the new file into the repository
#     - Go to terminal
#     - `ls` will show the new file along with README.md file
#     - `git staus` will show 'data_processing' in red
#     - `git add data_processing.ipny` will add the new file
#     -  `git status` will show the file as green
#     -  `git commit - m "message"` This will commit the new file
#     -   `git status` at thsi stage will display that "your repo is ahead of origin/master by 1 commit". this is because we commited the file but didi not push it to the original master branch.
#     - `git push -u origin master` this will push the file to the repository
#     - Check the repository and refresh the page.
#     - You will find the new file added there.

# %% [markdown]
# ### Revert and Reset
# - Revert and reset are tow useful codes to undo changes done to the repository
# - Rever
#
# - Make Changes to file data_processing
# - Write some more code and intetionally write it wrong.
# - Go to terminal and add the new file as before
#     - git add
#     - git commit
#     - git push
# - Here we have pushed it to the master itsef
# - **Note:** This is a peice of code that is errenous and will afftect the whole program or project.
# - Since the entire code is ow affected we need to get back to the stable version
# - `git log` this code will display all the commits thats done so far
#     - You can see the commit id which is very long code
#     - Also, the user who committed the code and other details
# - `git log --oneline` will enable you to see the shorter version of log which is easier to read
# - Revert
#     - `git revert head` will take the code back to the previous commit which was stable in this case.
#         - revert actually creates a new commit and new comit id is created.
#         - This will probably take you to **vim** mode which will disable your ability to enter furhter command.
#         - To get back to normal terminal window use `ESC, :, q, !` 'q' is for quit and q! is for quiting without saving
#     - Check the log again and you will find that even the revert is added to the log.
#     - Check the VS Code terminal and you will find that the erreneous code has been replaced.

# %% [markdown]
# ### Branching
# - Though revert and reset lets you get back to the previous version, it may still hamper the stable code, especially when many people are collborating.
# - Hence, branching
# - Branching creates a new branch with all the codes in the master. One may then edit or add new code to th ebranch and verify if it works.
# - After verifying the branch may be added to the master branch.
# - `git branch` lets you see the current branch
# - Creating new branch
# - `git checkout -b <branch name>` this command will create a new branch with the given name. "b" stands for branch
#     - in this eg we shall create a new branch named model using code `git checkout -b model`
# - runnig this command will create the branch and switch to the branch.
# - run `git branch` again and you will see two branches master and model. The * infront of model   indicates that the branch we are working on and any new commit will go into that branch.
# - HAving switched the branch lets go to VS Code and add new code to the python code.
#     - go to VS Code and create a new file model
# - Pusihng the model
#     - Note that when you push the code after commit, use the name of the branch currently in use and not the master
#     - git push origin <model>
# - Go to github and clik on the tab with master. inside you can see a new branch model has been added.
# - **Note**
#     - git push -u will push all the untracked files to the branch where as git push will add only the current file
#     - git push origin will add all the files to all the branches and git push origin <branch name> will add files to the particular branch.
# - Switch branches
#     - use command `git checkout <branch name>` this will switch to the desired branch.
#     - In case you entered a wrong branch name, it will display an error message.
#     - **note** using `git checkout -b <branch name >` creates a new branch
